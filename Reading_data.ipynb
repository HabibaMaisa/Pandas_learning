# %% [markdown]
# ## Reading data from CSV/Excel

# %%
import pandas as pd

# %%
df=pd.read_excel('Data.xlsx')

# %%
df
# Out:
#    ID  Marks
# 0   1     80
# 1   2     85
# 2   3     90
# 3   4     70
# 4   5     75

# %%
df=pd.read_excel('Data.xlsx',sheet_name='Sheet2')
df
# Out:
#    ID Name
# 0   1   Mm
# 1   2   Nn
# 2   3   Rr
# 3   4   Pp
# 4   5   Ss

# %%
dff=pd.read_csv('data1.csv')
dff
# Out:
#    ID   Age  Salary
# 0    1   32   80000
# 1    2   42   75000
# 2    3   30   70000
# 3    4   26   65000
# 4    5   45   65000

# %% [markdown]
# ## Reading dataset from Github using requests

# %%
# !pip install requests

# %%
import pandas as pd
import requests
from io import StringIO

# %% [markdown]
# Here,the request.get() function is used to send an HTTP GET request to the specified URL. This function returns a Response object and you have assigned it to the variable response.This object contains the server's response to the request.

# %%
url ='https://github.com/HabibaMaisa/Pandas_learning/raw/main/mental_health.csv'
response=requests.get(url)

# %% [markdown]
# The StringIO class from the module is used to create a file-like object from the text content of the response.response.text contains the content of the CSV file as a string and StringIO helps to treat this string as a file-like object that pd.read_csv can read.

# %%
csv_content = StringIO(response.text)

# %%
ddf=pd.read_csv(csv_content)
ddf.head()
# Out:
#    Person_ID  Age  Gender Occupation  Daily_Screen_Time  Social_Media_Usage  \
# 0          1   54    Male    Student               10.2                 7.5
# 1          2   44    Male    Student                6.8                 4.5
# 2          3   30    Male   Employed                5.5                 6.9
# 3          4   58    Male   Employed                5.6                 4.1
# 4          5   23  Female   Employed               10.1                 6.0
#
#    Night_Usage  Sleep_Hours  Stress_Level  Work_Study_Hours Physical_Activity  \
# 0            0          6.5             8               5.8               Low
# 1            0          5.1             4               7.9              High
# 2            0          3.5            10               9.4               Low
# 3            0          9.0             2               2.0              High
# 4            1          3.8             4               4.6               Low
#
# ...

# %%
ddf.shape
# Out:
# (2000, 18)

# %% [markdown]
# ## Reading Dataset from github using direct raw data URL

# %%
url='https://raw.githubusercontent.com/HabibaMaisa/Pandas_learning/refs/heads/main/mental_health.csv'
data=pd.read_csv(url)
data.head()
# Out:
#    Person_ID  Age  Gender Occupation  Daily_Screen_Time  Social_Media_Usage  \
# 0          1   54    Male    Student               10.2                 7.5
# 1          2   44    Male    Student                6.8                 4.5
# 2          3   30    Male   Employed                5.5                 6.9
# 3          4   58    Male   Employed                5.6                 4.1
# 4          5   23  Female   Employed               10.1                 6.0
#
#    Night_Usage  Sleep_Hours  Stress_Level  Work_Study_Hours Physical_Activity  \
# 0            0          6.5             8               5.8               Low
# 1            0          5.1             4               7.9              High
# 2            0          3.5            10               9.4               Low
# 3            0          9.0             2               2.0              High
# 4            1          3.8             4               4.6               Low
#
# ...

# %% [markdown]
# ## Reading dataset from Github using web get

# %%
# !pip install wget

# %%
import wget 
#replace the URL with raw URL of my CSV file on Github
url = 'https://raw.githubusercontent.com/HabibaMaisa/Pandas_learning/refs/heads/main/mental_health.csv'
#Use wget to download the CSV file
file_path=wget.download(url)
# Out:
# 100% [............................................................................] 125681 / 125681

# %%
data1=pd.read_csv(url)
data1
# Out:
#       Person_ID  Age  Gender  Occupation  Daily_Screen_Time  \
# 0             1   54    Male     Student               10.2
# 1             2   44    Male     Student                6.8
# 2             3   30    Male    Employed                5.5
# 3             4   58    Male    Employed                5.6
# 4             5   23  Female    Employed               10.1
# ...         ...  ...     ...         ...                ...
# 1995       1996   49  Female    Employed                4.8
# 1996       1997   33    Male    Employed                2.7
# 1997       1998   28    Male    Employed                2.6
# 1998       1999   56  Female     Student                3.2
# 1999       2000   38    Male  Unemployed                7.8
#
#       Social_Media_Usage  Night_Usage  Sleep_Hours  Stress_Level  \
# 0                    7.5            0          6.5             8
# 1                    4.5            0          5.1             4
# ...

# %%
data1.shape
# Out:
# (2000, 18)
