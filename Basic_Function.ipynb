# %%
import pandas as pd
df= pd.read_csv('mental_health.csv')

# %%
df.shape
# Out:
# (2000, 18)

# %%
row , col =df.shape

# %%
row
# Out:
# 2000

# %%
col
# Out:
# 18

# %%
df.head()
# Out:
#    Person_ID  Age  Gender Occupation  Daily_Screen_Time  Social_Media_Usage  \
# 0          1   54    Male    Student               10.2                 7.5
# 1          2   44    Male    Student                6.8                 4.5
# 2          3   30    Male   Employed                5.5                 6.9
# 3          4   58    Male   Employed                5.6                 4.1
# 4          5   23  Female   Employed               10.1                 6.0
#
#    Night_Usage  Sleep_Hours  Stress_Level  Work_Study_Hours Physical_Activity  \
# 0            0          6.5             8               5.8               Low
# 1            0          5.1             4               7.9              High
# 2            0          3.5            10               9.4               Low
# 3            0          9.0             2               2.0              High
# 4            1          3.8             4               4.6               Low
#
# ...

# %%
#top nth row
df.head(8)
# Out:
#    Person_ID  Age  Gender  Occupation  Daily_Screen_Time  Social_Media_Usage  \
# 0          1   54    Male     Student               10.2                 7.5
# 1          2   44    Male     Student                6.8                 4.5
# 2          3   30    Male    Employed                5.5                 6.9
# 3          4   58    Male    Employed                5.6                 4.1
# 4          5   23  Female    Employed               10.1                 6.0
# 5          6   36  Female     Student                5.3                 6.1
# 6          7   54  Female  Unemployed                4.1                 2.2
# 7          8   34    Male  Unemployed                2.8                 3.5
#
#    Night_Usage  Sleep_Hours  Stress_Level  Work_Study_Hours Physical_Activity  \
# 0            0          6.5             8               5.8               Low
# 1            0          5.1             4               7.9              High
# ...

# %%
# last nth row
df.tail(10)
# Out:
#       Person_ID  Age  Gender  Occupation  Daily_Screen_Time  \
# 1990       1991   53    Male  Unemployed                8.3
# 1991       1992   19    Male     Student                6.2
# 1992       1993   53  Female     Student                3.7
# 1993       1994   34  Female     Student               11.9
# 1994       1995   21    Male  Unemployed               10.2
# 1995       1996   49  Female    Employed                4.8
# 1996       1997   33    Male    Employed                2.7
# 1997       1998   28    Male    Employed                2.6
# 1998       1999   56  Female     Student                3.2
# 1999       2000   38    Male  Unemployed                7.8
#
#       Social_Media_Usage  Night_Usage  Sleep_Hours  Stress_Level  \
# 1990                 2.8            1          7.7             4
# 1991                 1.1            1          6.6             8
# 1992                 2.6            0          6.9             1
# ...

# %%
# range of entries
df[5:10]
# Out:
#    Person_ID  Age  Gender  Occupation  Daily_Screen_Time  Social_Media_Usage  \
# 5          6   36  Female     Student                5.3                 6.1
# 6          7   54  Female  Unemployed                4.1                 2.2
# 7          8   34    Male  Unemployed                2.8                 3.5
# 8          9   38    Male    Employed                6.7                 5.5
# 9         10   26    Male    Employed                6.8                 1.5
#
#    Night_Usage  Sleep_Hours  Stress_Level  Work_Study_Hours Physical_Activity  \
# 5            1          3.4             2               7.4               Low
# 6            0          8.3             3               7.3               Low
# 7            1          4.8             4               8.4            Medium
# 8            0          6.9             4               5.0               Low
# 9            0          5.0            10               7.4            Medium
#
# ...

# %%
#accesing the columns
df.Age
# Out:
# 0       54
# 1       44
# 2       30
# 3       58
# 4       23
#         ..
# 1995    49
# 1996    33
# 1997    28
# 1998    56
# 1999    38
# Name: Age, Length: 2000, dtype: int64

# %%
df.Daily_Screen_Time
# Out:
# 0       10.2
# 1        6.8
# 2        5.5
# 3        5.6
# 4       10.1
#         ...
# 1995     4.8
# 1996     2.7
# 1997     2.6
# 1998     3.2
# 1999     7.8
# Name: Daily_Screen_Time, Length: 2000, dtype: float64

# %%
df.columns
# Out:
# Index(['Person_ID', 'Age', 'Gender', 'Occupation', 'Daily_Screen_Time',
#        'Social_Media_Usage', 'Night_Usage', 'Sleep_Hours', 'Stress_Level',
#        'Work_Study_Hours', 'Physical_Activity', 'Social_Interaction_Score',
#        'Caffeine_Intake', 'Smoking', 'Alcohol', 'Depression', 'Anxiety',
#        'Burnout'],
#       dtype='object')

# %%
#accesing nth column
df[['Occupation']].head()
# Out:
#   Occupation
# 0    Student
# 1    Student
# 2   Employed
# 3   Employed
# 4   Employed

# %%
df[['Age','Gender']]
# Out:
#       Age  Gender
# 0      54    Male
# 1      44    Male
# 2      30    Male
# 3      58    Male
# 4      23  Female
# ...   ...     ...
# 1995   49  Female
# 1996   33    Male
# 1997   28    Male
# 1998   56  Female
# 1999   38    Male
#
# [2000 rows x 2 columns]

# %%
type(df['Age'])
# Out:
# pandas.core.series.Series

# %%
type(df[['Age']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Basic Statiscal Functions

# %%
url='https://raw.githubusercontent.com/HabibaMaisa/Pandas_learning/refs/heads/main/mental_health.csv'
df=pd.read_csv(url)
df.head()
# Out:
#    Person_ID  Age  Gender Occupation  Daily_Screen_Time  Social_Media_Usage  \
# 0          1   54    Male    Student               10.2                 7.5
# 1          2   44    Male    Student                6.8                 4.5
# 2          3   30    Male   Employed                5.5                 6.9
# 3          4   58    Male   Employed                5.6                 4.1
# 4          5   23  Female   Employed               10.1                 6.0
#
#    Night_Usage  Sleep_Hours  Stress_Level  Work_Study_Hours Physical_Activity  \
# 0            0          6.5             8               5.8               Low
# 1            0          5.1             4               7.9              High
# 2            0          3.5            10               9.4               Low
# 3            0          9.0             2               2.0              High
# 4            1          3.8             4               4.6               Low
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2000, step=1)

# %%
len(df)
# Out:
# 2000

# %%
#MAX
df['Daily_Screen_Time'].max()
# Out:
# 12.0

# %%
#MIN
df['Daily_Screen_Time'].min()
# Out:
# 2.0

# %%
df['Daily_Screen_Time'].mean()
# Out:
# np.float64(6.943149999999999)

# %%
df['Daily_Screen_Time'].std()
# Out:
# 2.8824151741409647

# %%
df['Daily_Screen_Time'].mode()
# Out:
# 0    7.8
# Name: Daily_Screen_Time, dtype: float64

# %%
df['Daily_Screen_Time'].value_counts()
# Out:
# Daily_Screen_Time
# 7.8     34
# 8.8     31
# 8.0     31
# 3.3     29
# 2.5     28
#         ..
# 5.7     11
# 7.2     11
# 12.0     9
# 2.0      6
# 9.9      6
# Name: count, Length: 101, dtype: int64

# %%
#25%
df['Daily_Screen_Time'].quantile(0.25)
# Out:
# np.float64(4.5)

# %%
#100%
df['Daily_Screen_Time'].quantile(1)
# Out:
# np.float64(12.0)

# %%
df['Daily_Screen_Time'].quantile(0)
# Out:
# np.float64(2.0)

# %%
df.describe()
# Out:
#          Person_ID          Age  Daily_Screen_Time  Social_Media_Usage  \
# count  2000.000000  2000.000000        2000.000000         2000.000000
# mean   1000.500000    37.694000           6.943150            4.436400
# std     577.494589    12.614195           2.882415            2.011725
# min       1.000000    16.000000           2.000000            1.000000
# 25%     500.750000    27.000000           4.500000            2.700000
# 50%    1000.500000    38.000000           6.800000            4.400000
# 75%    1500.250000    49.000000           9.400000            6.200000
# max    2000.000000    59.000000          12.000000            8.000000
#
#        Night_Usage  Sleep_Hours  Stress_Level  Work_Study_Hours  \
# count  2000.000000   2000.00000   2000.000000       2000.000000
# mean      0.489500      6.00765      5.409500          7.005650
# std       0.500015      1.70631      2.885129          2.846442
# min       0.000000      3.00000      1.000000          2.000000
# ...

# %% [markdown]
# ## value Sorting

# %%
df.head()
# Out:
#    Person_ID  Age  Gender Occupation  Daily_Screen_Time  Social_Media_Usage  \
# 0          1   54    Male    Student               10.2                 7.5
# 1          2   44    Male    Student                6.8                 4.5
# 2          3   30    Male   Employed                5.5                 6.9
# 3          4   58    Male   Employed                5.6                 4.1
# 4          5   23  Female   Employed               10.1                 6.0
#
#    Night_Usage  Sleep_Hours  Stress_Level  Work_Study_Hours Physical_Activity  \
# 0            0          6.5             8               5.8               Low
# 1            0          5.1             4               7.9              High
# 2            0          3.5            10               9.4               Low
# 3            0          9.0             2               2.0              High
# 4            1          3.8             4               4.6               Low
#
# ...

# %%
df['Social_Media_Usage'].sort_values()
# Out:
# 1079    1.0
# 1135    1.0
# 1904    1.0
# 1914    1.0
# 1445    1.0
#        ...
# 707     8.0
# 940     8.0
# 305     8.0
# 1693    8.0
# 927     8.0
# Name: Social_Media_Usage, Length: 2000, dtype: float64

# %%
df['Social_Media_Usage'].sort_values(ascending=False)
# Out:
# 1693    8.0
# 927     8.0
# 1637    8.0
# 1780    8.0
# 305     8.0
#        ...
# 919     1.0
# 1135    1.0
# 1977    1.0
# 304     1.0
# 1904    1.0
# Name: Social_Media_Usage, Length: 2000, dtype: float64

# %%
df.nlargest(10,'Caffeine_Intake')
# Out:
#     Person_ID  Age  Gender  Occupation  Daily_Screen_Time  Social_Media_Usage  \
# 4           5   23  Female    Employed               10.1                 6.0
# 6           7   54  Female  Unemployed                4.1                 2.2
# 10         11   26    Male  Unemployed               10.4                 3.5
# 20         21   45    Male  Unemployed               11.3                 5.2
# 24         25   48    Male     Student                6.8                 1.7
# 26         27   37  Female     Student                3.6                 7.1
# 29         30   42    Male    Employed                7.6                 6.2
# 31         32   43  Female  Unemployed                2.7                 4.5
# 33         34   30  Female  Unemployed                3.2                 7.7
# 39         40   24    Male     Student                7.5                 1.1
#
#     Night_Usage  Sleep_Hours  Stress_Level  Work_Study_Hours  \
# ...

# %%
df.nsmallest(10,'Caffeine_Intake')
# Out:
#     Person_ID  Age  Gender  Occupation  Daily_Screen_Time  Social_Media_Usage  \
# 2           3   30    Male    Employed                5.5                 6.9
# 3           4   58    Male    Employed                5.6                 4.1
# 7           8   34    Male  Unemployed                2.8                 3.5
# 11         12   39    Male  Unemployed                4.2                 4.7
# 14         15   39    Male  Unemployed               10.2                 6.7
# 16         17   37    Male    Employed                6.6                 6.6
# 23         24   36  Female    Employed                2.3                 2.0
# 28         29   40  Female  Unemployed               11.7                 2.5
# 32         33   31  Female  Unemployed                6.2                 2.1
# 35         36   18  Female     Student               11.4                 7.0
#
#     Night_Usage  Sleep_Hours  Stress_Level  Work_Study_Hours  \
# ...
